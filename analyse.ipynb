# %%
from src import Analyse
import matplotlib.pyplot as plt

# %%
c_name = 'TATAMOTORS'
details = Analyse(c_name)

previous_values = details.getAPIValues()
future_values = details.predictionValues()
# Out:
# Epoch 1/300
# 1/1 [==============================] - 7s 7s/step - loss: 54404947968.0000
# Epoch 2/300
# 1/1 [==============================] - 0s 19ms/step - loss: 54237913088.0000
# Epoch 3/300
# 1/1 [==============================] - 0s 20ms/step - loss: 54355582976.0000
# Epoch 4/300
# 1/1 [==============================] - 0s 19ms/step - loss: 54557831168.0000
# Epoch 5/300
# 1/1 [==============================] - 0s 19ms/step - loss: 53768630272.0000
# Epoch 6/300
# 1/1 [==============================] - 0s 19ms/step - loss: 53568839680.0000
# Epoch 7/300
# 1/1 [==============================] - 0s 19ms/step - loss: 53347475456.0000
# Epoch 8/300
# 1/1 [==============================] - 0s 21ms/step - loss: 52869353472.0000
# Epoch 9/300
# 1/1 [==============================] - 0s 22ms/step - loss: 52659912704.0000
# Epoch 10/300
# 1/1 [==============================] - 0s 20ms/step - loss: 52446674944.0000
# Epoch 11/300
# ...

# %%
for f_value in future_values:
    print(f'{f_value} : {future_values[f_value]} : length {len(future_values[f_value])}')
# Out:
# p_years : [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024] : length 13
# p_revenue : [46079.32, 51106.57, 63668.57, 80769.95, 89581.95, 111601.19, 141577.27, 157023.35, 195619.69, 248163.14, 275235.23, 342874.59, 434984.12] : length 13
# p_income : [1339.64, 1074.12, -226.64, -2947.63, -2363.41, 498.68, 6485.64, 5200.19, -1097.24, -14270.09, -11441.47, 2414.29, 31399.09] : length 13
# years : [2025, 2026, 2027, 2028, 2029] : length 5
# revenue : [486285.8, 621217.3, 750322.06, 895410.2, 1101493.2] : length 5
# income : [25108.76, -5319.84, -69022.39, -55258.01, 11684.61] : length 5

# %%
plt.figure(figsize=(8, 4))
plt.plot(future_values['p_years'], future_values['p_revenue'])
plt.plot(future_values['years'], future_values['revenue'])

# %%
plt.figure(figsize=(8, 4))
plt.plot(future_values['p_years'], future_values['p_income'])
plt.plot(future_values['years'], future_values['income'])
