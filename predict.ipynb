# %%
from project import add_values, company_details
from analysis import PredictValues
import matplotlib.pyplot as plt

# %%
c_details = company_details('TATAMOTORS')

for data in c_details:
    print(f'{data} : {c_details[data]}')
# Out:
# bussiness : Tata Motors Limited designs, develops, manufactures, and sells various automotive vehicles. The company offers passenger cars; sports utility vehicles; intermediate and light commercial vehicles; small, medium, and heavy commercial vehicles; defense vehicles; pickups, wingers, buses, vans, and trucks; and electric vehicles, as well as related spare parts and accessories. It also manufactures engines for industrial applications, and aggregates comprising axles and transmissions for commercial vehicles; and factory automation equipment, as well as provides information technology and vehicle financing services. The company offers its products under the Tata, Daewoo, Harrier, Safari, Fiat, Nexon, Altroz, Punch, Tiago, Tigor, Jaguar, and Land Rover brands. It operates in India, China, the United States, the United Kingdom, rest of Europe, and internationally. It offers its products to fleet owners, transporters, government agencies, defense, public transport utilities, small a
# ...

# %%
get_prev_values = add_values(c_details['years'], c_details['revenue'], c_details['net_income'])

for value in get_prev_values:
    print(f'{value} : {get_prev_values[value]}')
    print(f'{value} : {len(get_prev_values[value])}')
# Out:
# years : [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
# years : 13
# revenue : [46079.32, 51106.57, 63668.57, 80769.95, 89581.95, 111601.19, 141577.27, 157023.35, 195619.69, 248163.14, 275235.23, 342874.59, 434984.12]
# revenue : 13
# net_income : [1339.64, 1074.12, -226.64, -2947.63, -2363.41, 498.68, 6485.64, 5200.19, -1097.24, -14270.09, -11441.47, 2414.29, 31399.09]
# net_income : 13

# %%
plt.plot(get_prev_values['years'], get_prev_values['net_income'])

# %%
predict_revenue = PredictValues(get_prev_values['years'], get_prev_values['revenue'])
future_revenue = predict_revenue.get_future_values(c_details['revenue'], 2030)
# Out:
# Epoch 1/300
# 1/1 [==============================] - 7s 7s/step - loss: 59475099648.0000
# Epoch 2/300
# 1/1 [==============================] - 0s 20ms/step - loss: 58049114112.0000
# Epoch 3/300
# 1/1 [==============================] - 0s 21ms/step - loss: 56828612608.0000
# Epoch 4/300
# 1/1 [==============================] - 0s 20ms/step - loss: 55898648576.0000
# Epoch 5/300
# 1/1 [==============================] - 0s 21ms/step - loss: 54831587328.0000
# Epoch 6/300
# 1/1 [==============================] - 0s 21ms/step - loss: 53753708544.0000
# Epoch 7/300
# 1/1 [==============================] - 0s 20ms/step - loss: 53031198720.0000
# Epoch 8/300
# 1/1 [==============================] - 0s 20ms/step - loss: 52159574016.0000
# Epoch 9/300
# 1/1 [==============================] - 0s 21ms/step - loss: 50631319552.0000
# Epoch 10/300
# 1/1 [==============================] - 0s 17ms/step - loss: 49741717504.0000
# Epoch 11/300
# ...

# %%
for value in future_revenue:
    print(f'{value} : {future_revenue[value]}')
# Out:
# values : [25214.07, -5333.52, -69109.11, -55457.03, 11714.76, 152093.3, 122192.56]
# years : [2024, 2025, 2026, 2027, 2028, 2029, 2030]

# %%
plt.figure(figsize=(12, 6))
plt.plot(c_details['years'], c_details['net_income'])
plt.plot(future_revenue['years'], future_revenue['values'])

# %%
predict_revenue = PredictValues(get_prev_values['years'], get_prev_values['net_income'])
future_revenue = predict_revenue.get_future_values(c_details['net_income'], 2030)
# Out:
# Epoch 1/300
# 1/1 [==============================] - 7s 7s/step - loss: 140894560.0000
# Epoch 2/300
# 1/1 [==============================] - 0s 19ms/step - loss: 139760128.0000
# Epoch 3/300
# 1/1 [==============================] - 0s 23ms/step - loss: 139347872.0000
# Epoch 4/300
# 1/1 [==============================] - 0s 19ms/step - loss: 138956672.0000
# Epoch 5/300
# 1/1 [==============================] - 0s 22ms/step - loss: 138064144.0000
# Epoch 6/300
# 1/1 [==============================] - 0s 21ms/step - loss: 138232240.0000
# Epoch 7/300
# 1/1 [==============================] - 0s 22ms/step - loss: 137839264.0000
# Epoch 8/300
# 1/1 [==============================] - 0s 22ms/step - loss: 137590960.0000
# Epoch 9/300
# 1/1 [==============================] - 0s 21ms/step - loss: 136840128.0000
# Epoch 10/300
# 1/1 [==============================] - 0s 25ms/step - loss: 136507456.0000
# Epoch 11/300
# ...
