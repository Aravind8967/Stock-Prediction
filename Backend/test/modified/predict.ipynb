# %%
from src import PredictValues
import matplotlib.pyplot as plt

# %%
predict = PredictValues('TATAMOTORS')
get_future_values = predict.getFutureValues(10)
# Out:
# Epoch 1/300
# 1/1 [==============================] - 2s 2s/step - loss: 55569195008.0000
# Epoch 2/300
# 1/1 [==============================] - 0s 7ms/step - loss: 55363182592.0000
# Epoch 3/300
# 1/1 [==============================] - 0s 7ms/step - loss: 54984499200.0000
# Epoch 4/300
# 1/1 [==============================] - 0s 7ms/step - loss: 54607425536.0000
# Epoch 5/300
# 1/1 [==============================] - 0s 7ms/step - loss: 54215127040.0000
# Epoch 6/300
# 1/1 [==============================] - 0s 6ms/step - loss: 53851312128.0000
# Epoch 7/300
# 1/1 [==============================] - 0s 6ms/step - loss: 53482250240.0000
# Epoch 8/300
# 1/1 [==============================] - 0s 8ms/step - loss: 52967133184.0000
# Epoch 9/300
# 1/1 [==============================] - 0s 6ms/step - loss: 52556718080.0000
# Epoch 10/300
# 1/1 [==============================] - 0s 6ms/step - loss: 52234825728.0000
# Epoch 11/300
# ...

# %%
for val in get_future_values:
    print(f'{val} : {get_future_values[val]}')
# Out:
# years : [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
# revenue : [46079.32, 51106.57, 63668.57, 80769.95, 89581.95, 111601.19, 141577.27, 157023.35, 195619.69, 248163.14, 275235.23, 342874.59, 434984.12]
# income : [1339.64, 1074.12, -226.64, -2947.63, -2363.41, 498.68, 6485.64, 5200.19, -1097.24, -14270.09, -11441.47, 2414.29, 31399.09]
# eps : [3.64, 2.92, -0.62, -8.01, -6.42, 1.35, 17.62, 14.13, -2.98, -38.76, -31.08, 6.56, 85.3]
# roe : [2.96, 2.37, -0.5, -6.5, -5.21, 1.1, 14.31, 11.47, -2.42, -31.49, -25.24, 5.33, 69.28]
# operating_expence : [89441.99, 89627.71, 111871.81, 138962.54]
# profit_margin : [2.91, 2.1, -0.36, -3.65, -2.64, 0.45, 4.58, 3.31, -0.56, -5.75, -4.16, 0.7, 7.22]
# shareholders_equity : [50330.29, 44561.24, 45321.79, 84918.02]
# outstanding_shares : 368.12
# line_data : {'support1': 584.25, 'support2': 547.85, 'support3': 440.85, 'resistance1': 691.25, 'resistance2': 761.85, 'resistance3': 868.85}
# ...

# %%
plt.figure(figsize=(12, 6))
plt.plot(get_future_values['years'], get_future_values['revenue'])

# %%
plt.figure(figsize=(12, 6))
plt.plot(get_future_values['years'], get_future_values['income'])

# %%
plt.figure(figsize=(12, 6))
plt.plot(get_future_values['years'], get_future_values['revenue'])
plt.plot(get_future_values['future_years'], get_future_values['future_revenue'])

# %%
plt.figure(figsize=(12, 6))
plt.plot(get_future_values['years'], get_future_values['income'])
plt.plot(get_future_values['future_years'], get_future_values['future_income'])
