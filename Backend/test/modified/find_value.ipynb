# %%
from src.FindValues import FindValues
import matplotlib.pyplot as plt

# %%
c_name = 'SBILIFE'
find_value = FindValues(c_name)

details = find_value.getCompanyDetails()

# %%
print(details['shareholders_equity'][-1])
# Out:
# 14908.56

# %%
for val in details:
    print(f'{val} : {details[val]}')
# Out:
# years : [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
# revenue : [19768.85, 19958.63, 19411.76, 31778.99, 32084.07, 31204.97, 51085.66, 51576.08, 50162.9, 82121.68, 82911.24, 80639.04, 132018.13]
# income : [661.43, 684.18, 781.67, 860.38, 889.98, 1016.8, 1119.19, 1157.69, 1322.66, 1455.85, 1506.0, 1720.57, 1893.78]
# eps : [6.6, 6.83, 7.8, 8.59, 8.88, 10.15, 11.17, 11.55, 13.2, 14.53, 15.03, 17.17, 18.9]
# roe : [5.08, 5.26, 6.0, 6.61, 6.84, 7.81, 8.6, 8.89, 10.16, 11.18, 11.57, 13.22, 14.55]
# operating_expence : [0.0, 0.0, 0.0, 0.0]
# profit_margin : [3.35, 3.43, 4.03, 2.71, 2.77, 3.26, 2.19, 2.24, 2.64, 1.77, 1.82, 2.13, 1.43]
# shareholders_equity : [10400.44, 11622.31, 13017.48, 14908.56]
# outstanding_shares : 100.21
# line_data : {'support1': 1359.37, 'support2': 1288.23, 'support3': 1132.78, 'resistance1': 1514.82, 'resistance2': 1599.13, 'resistance3': 1754.58}
# ...

# %%
plt.figure(figsize=(8,4))
plt.plot(details['years'], details['eps'])
plt.plot(details['years'], details['roe'])

# %%
plt.figure(figsize=(8,4))
plt.plot(details['years'], details['profit_margin'])
