# %%
from src import SharePricePrediction
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
c_name = 'ITC'
class_prediction = SharePricePrediction(c_name=c_name)
prediction = class_prediction.prediction('2022-03-23', '2025-03-20')
# Out:
# Epoch 1/100
# 19/19 [==============================] - 8s 98ms/step - loss: 141393.0469 - mean_absolute_error: 369.3742 - val_loss: 236765.2500 - val_mean_absolute_error: 486.3130
# Epoch 2/100
# 19/19 [==============================] - 0s 18ms/step - loss: 140493.5469 - mean_absolute_error: 368.1609 - val_loss: 235466.8594 - val_mean_absolute_error: 484.9763
# Epoch 3/100
# 19/19 [==============================] - 0s 16ms/step - loss: 138825.4375 - mean_absolute_error: 365.8838 - val_loss: 231709.9688 - val_mean_absolute_error: 481.0873
# Epoch 4/100
# 19/19 [==============================] - 0s 20ms/step - loss: 135157.6094 - mean_absolute_error: 360.8318 - val_loss: 225772.6562 - val_mean_absolute_error: 474.8765
# Epoch 5/100
# 19/19 [==============================] - 0s 19ms/step - loss: 129371.9062 - mean_absolute_error: 352.7165 - val_loss: 215595.8594 - val_mean_absolute_error: 464.0375
# Epoch 6/100
# ...

# %%
print(prediction)
# Out:
# {'dates_train': array([Timestamp('2022-03-23 00:00:00'), Timestamp('2022-03-24 00:00:00'),
#        Timestamp('2022-03-25 00:00:00'), Timestamp('2022-03-28 00:00:00'),
#        Timestamp('2022-03-29 00:00:00'), Timestamp('2022-03-30 00:00:00'),
#        Timestamp('2022-03-31 00:00:00'), Timestamp('2022-04-01 00:00:00'),
#        Timestamp('2022-04-04 00:00:00'), Timestamp('2022-04-05 00:00:00'),
#        Timestamp('2022-04-06 00:00:00'), Timestamp('2022-04-07 00:00:00'),
#        Timestamp('2022-04-08 00:00:00'), Timestamp('2022-04-11 00:00:00'),
#        Timestamp('2022-04-12 00:00:00'), Timestamp('2022-04-13 00:00:00'),
#        Timestamp('2022-04-18 00:00:00'), Timestamp('2022-04-19 00:00:00'),
#        Timestamp('2022-04-20 00:00:00'), Timestamp('2022-04-21 00:00:00'),
#        Timestamp('2022-04-22 00:00:00'), Timestamp('2022-04-25 00:00:00'),
#        Timestamp('2022-04-26 00:00:00'), Timestamp('2022-04-27 00:00:00'),
# ...

# %%
plt.plot(prediction['dates_train'], prediction['train_prediction'])
plt.plot(prediction['dates_train'], prediction['y_train'])
